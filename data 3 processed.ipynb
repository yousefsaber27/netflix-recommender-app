# %%
import pandas as pd
import numpy as np
import requests
from tmdbv3api import TMDb
from tmdbv3api import Movie

import json

# %%
url = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"

headers = {"User-Agent": "Mozilla/5.0"}
response = requests.get(url, headers=headers)

tables = pd.read_html(response.text, header=0)

df1 = tables[2]
df2 = tables[3]
df3 = tables[4]
df4 = tables[5]
# Out:
# C:\Users\youse\AppData\Local\Temp\ipykernel_21736\3707419593.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(response.text, header=0)

# %%
df = pd.concat([df1, df2, df3, df4], ignore_index=True)
df
# Out:
#              Opening  Opening.1                  Title  \
# 0      J A N U A R Y          5         The Final Year
# 1      J A N U A R Y          5              Bomb City
# 2      J A N U A R Y         12    The Hurricane Heist
# 3      J A N U A R Y         12       Super Troopers 2
# 4      J A N U A R Y         12  Leaning Into The Wind
# ..               ...        ...                    ...
# 245  D E C E M B E R         21             Second Act
# 246  D E C E M B E R         25        Holmes & Watson
# 247  D E C E M B E R         25                   Vice
# 248  D E C E M B E R         25    On the Basis of Sex
# 249  D E C E M B E R         25              Destroyer
#
#                                     Production company  \
# 0                  LD Entertainment / Blue Sky Studios
# 1                                                  A24
# 2                                          Saban Films
# 3                                         IFC Midnight
# 4                                A24 / New Line Cinema
# ..                                                 ...
# 245                                  STX Entertainment
# 246  Columbia Pictures / Gary Sanchez Productions /...
# 247          Annapurna Pictures / Plan B Entertainment
# 248                                     Focus Features
# 249                                 Annapurna Pictures
#
#                                          Cast and crew   Ref.
# 0    Adam Robitel (director); Leigh Whannell (scree...    [2]
# 1    Christopher Radcliff (director/screenplay); La...    [3]
# 2    Jaume Collet-Serra (director); Byron Willinger...    [4]
# 3    Babak Najafi (director); John S. Newman, Chris...    [5]
# 4    Brett Donowho (director); Nicolas Aaron Mezzan...    [6]
# ..                                                 ...    ...
# 245  Peter Segal (director); Justin Zackham, Elaine...  [238]
# 246  Etan Cohen (director/screenplay); Will Ferrell...  [142]
# 247  Adam McKay (director/screenplay); Christian Ba...  [117]
# 248  Mimi Leder (director); Daniel Stiepleman (scre...  [207]
# 249  Karyn Kusama (director); Phil Hay, Matt Manfre...  [239]
#
# [250 rows x 6 columns]

# %%
tmdb = TMDb()
tmdb.api_key = '16a2e771876623fb5e75e805c1b8b586'

# %%
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        np.NaN

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
df
# Out:
#              Opening  Opening.1                  Title  \
# 0      J A N U A R Y          5         The Final Year
# 1      J A N U A R Y          5              Bomb City
# 2      J A N U A R Y         12    The Hurricane Heist
# 3      J A N U A R Y         12       Super Troopers 2
# 4      J A N U A R Y         12  Leaning Into The Wind
# ..               ...        ...                    ...
# 245  D E C E M B E R         21             Second Act
# 246  D E C E M B E R         25        Holmes & Watson
# 247  D E C E M B E R         25                   Vice
# 248  D E C E M B E R         25    On the Basis of Sex
# 249  D E C E M B E R         25              Destroyer
#
#                                     Production company  \
# 0                  LD Entertainment / Blue Sky Studios
# 1                                                  A24
# 2                                          Saban Films
# 3                                         IFC Midnight
# 4                                A24 / New Line Cinema
# ..                                                 ...
# 245                                  STX Entertainment
# 246  Columbia Pictures / Gary Sanchez Productions /...
# 247          Annapurna Pictures / Plan B Entertainment
# 248                                     Focus Features
# 249                                 Annapurna Pictures
#
#                                          Cast and crew   Ref.  \
# 0    Adam Robitel (director); Leigh Whannell (scree...    [2]
# 1    Christopher Radcliff (director/screenplay); La...    [3]
# 2    Jaume Collet-Serra (director); Byron Willinger...    [4]
# 3    Babak Najafi (director); John S. Newman, Chris...    [5]
# 4    Brett Donowho (director); Nicolas Aaron Mezzan...    [6]
# ..                                                 ...    ...
# 245  Peter Segal (director); Justin Zackham, Elaine...  [238]
# 246  Etan Cohen (director/screenplay); Will Ferrell...  [142]
# 247  Adam McKay (director/screenplay); Christian Ba...  [117]
# 248  Mimi Leder (director); Daniel Stiepleman (scre...  [207]
# 249  Karyn Kusama (director); Phil Hay, Matt Manfre...  [239]
#
#                                         genres
# 0                                  Documentary
# 1                                  Drama Crime
# 2              Action Adventure Crime Thriller
# 3                         Comedy Crime Mystery
# 4                                  Documentary
# ..                                         ...
# 245                             Romance Comedy
# 246                       Comedy Mystery Crime
# 247  Thriller Science Fiction Action Adventure
# 248                              Drama History
# 249                                      Drama
#
# [250 rows x 7 columns]

# %%
df_2018 = df[['Title','Cast and crew','genres']]
df_2018
# Out:
#                      Title                                      Cast and crew  \
# 0           The Final Year  Adam Robitel (director); Leigh Whannell (scree...
# 1                Bomb City  Christopher Radcliff (director/screenplay); La...
# 2      The Hurricane Heist  Jaume Collet-Serra (director); Byron Willinger...
# 3         Super Troopers 2  Babak Najafi (director); John S. Newman, Chris...
# 4    Leaning Into The Wind  Brett Donowho (director); Nicolas Aaron Mezzan...
# ..                     ...                                                ...
# 245             Second Act  Peter Segal (director); Justin Zackham, Elaine...
# 246        Holmes & Watson  Etan Cohen (director/screenplay); Will Ferrell...
# 247                   Vice  Adam McKay (director/screenplay); Christian Ba...
# 248    On the Basis of Sex  Mimi Leder (director); Daniel Stiepleman (scre...
# 249              Destroyer  Karyn Kusama (director); Phil Hay, Matt Manfre...
#
#                                         genres
# 0                                  Documentary
# 1                                  Drama Crime
# 2              Action Adventure Crime Thriller
# 3                         Comedy Crime Mystery
# 4                                  Documentary
# ..                                         ...
# 245                             Romance Comedy
# 246                       Comedy Mystery Crime
# 247  Thriller Science Fiction Action Adventure
# 248                              Drama History
# 249                                      Drama
#
# [250 rows x 3 columns]

# %% [markdown]
# **Extract Directors**

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))
# Out:
# C:\Users\youse\AppData\Local\Temp\ipykernel_21736\1424833719.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))

# %%
df_2018
# Out:
#                      Title                                      Cast and crew  \
# 0           The Final Year  Adam Robitel (director); Leigh Whannell (scree...
# 1                Bomb City  Christopher Radcliff (director/screenplay); La...
# 2      The Hurricane Heist  Jaume Collet-Serra (director); Byron Willinger...
# 3         Super Troopers 2  Babak Najafi (director); John S. Newman, Chris...
# 4    Leaning Into The Wind  Brett Donowho (director); Nicolas Aaron Mezzan...
# ..                     ...                                                ...
# 245             Second Act  Peter Segal (director); Justin Zackham, Elaine...
# 246        Holmes & Watson  Etan Cohen (director/screenplay); Will Ferrell...
# 247                   Vice  Adam McKay (director/screenplay); Christian Ba...
# 248    On the Basis of Sex  Mimi Leder (director); Daniel Stiepleman (scre...
# 249              Destroyer  Karyn Kusama (director); Phil Hay, Matt Manfre...
#
#                                         genres  \
# 0                                  Documentary
# 1                                  Drama Crime
# 2              Action Adventure Crime Thriller
# 3                         Comedy Crime Mystery
# 4                                  Documentary
# ..                                         ...
# 245                             Romance Comedy
# 246                       Comedy Mystery Crime
# 247  Thriller Science Fiction Action Adventure
# 248                              Drama History
# 249                                      Drama
#
#                                          director_name
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 245                                        Peter Segal
# 246                                         Etan Cohen
# 247                                         Adam McKay
# 248                                         Mimi Leder
# 249                                       Karyn Kusama
#
# [250 rows x 4 columns]

# %% [markdown]
# **Actor 1**

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# C:\Users\youse\AppData\Local\Temp\ipykernel_21736\1003472989.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))

# %% [markdown]
# **Actor 2**

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# C:\Users\youse\AppData\Local\Temp\ipykernel_21736\473373560.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))

# %% [markdown]
# **Actor 3**

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2018
# Out:
#                      Title                                      Cast and crew  \
# 0           The Final Year  Adam Robitel (director); Leigh Whannell (scree...
# 1                Bomb City  Christopher Radcliff (director/screenplay); La...
# 2      The Hurricane Heist  Jaume Collet-Serra (director); Byron Willinger...
# 3         Super Troopers 2  Babak Najafi (director); John S. Newman, Chris...
# 4    Leaning Into The Wind  Brett Donowho (director); Nicolas Aaron Mezzan...
# ..                     ...                                                ...
# 245             Second Act  Peter Segal (director); Justin Zackham, Elaine...
# 246        Holmes & Watson  Etan Cohen (director/screenplay); Will Ferrell...
# 247                   Vice  Adam McKay (director/screenplay); Christian Ba...
# 248    On the Basis of Sex  Mimi Leder (director); Daniel Stiepleman (scre...
# 249              Destroyer  Karyn Kusama (director); Phil Hay, Matt Manfre...
#
#                                         genres  \
# 0                                  Documentary
# 1                                  Drama Crime
# 2              Action Adventure Crime Thriller
# 3                         Comedy Crime Mystery
# 4                                  Documentary
# ..                                         ...
# 245                             Romance Comedy
# 246                       Comedy Mystery Crime
# 247  Thriller Science Fiction Action Adventure
# 248                              Drama History
# 249                                      Drama
#
#                                          director_name  \
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 245                                        Peter Segal
# 246                                         Etan Cohen
# 247                                         Adam McKay
# 248                                         Mimi Leder
# 249                                       Karyn Kusama
#
#                                    actor_1_name            actor_2_name  \
# 0                                     Lin Shaye           Angus Sampson
# 1    Lauren Wolkstein (director); Alex Pettyfer  James Freedson-Jackson
# 2                                   Liam Neeson            Vera Farmiga
# 3                              Taraji P. Henson    Jahi Di'Allo Winston
# 4                                  Bruce Willis             Cole Hauser
# ..                                          ...                     ...
# 245                              Jennifer Lopez             Leah Remini
# 246                                Will Ferrell          John C. Reilly
# 247                              Christian Bale               Amy Adams
# 248                              Felicity Jones            Armie Hammer
# 249                               Nicole Kidman          Sebastian Stan
#
#         actor_3_name
# 0     Leigh Whannell
# 1      Emily Althaus
# 2     Patrick Wilson
# 3        Billy Brown
# 4      Shawn Ashmore
# ..               ...
# 245  Vanessa Hudgens
# 246     Rebecca Hall
# 247     Steve Carell
# 248   Justin Theroux
# 249     Toby Kebbell
#
# [250 rows x 7 columns]

# %%
df_2018 = df_2018.rename(columns={'Title':'movie_title'})

# %%
new_df18 = df_2018.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df18
# Out:
#                                          director_name  \
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 245                                        Peter Segal
# 246                                         Etan Cohen
# 247                                         Adam McKay
# 248                                         Mimi Leder
# 249                                       Karyn Kusama
#
#                                    actor_1_name            actor_2_name  \
# 0                                     Lin Shaye           Angus Sampson
# 1    Lauren Wolkstein (director); Alex Pettyfer  James Freedson-Jackson
# 2                                   Liam Neeson            Vera Farmiga
# 3                              Taraji P. Henson    Jahi Di'Allo Winston
# 4                                  Bruce Willis             Cole Hauser
# ..                                          ...                     ...
# 245                              Jennifer Lopez             Leah Remini
# 246                                Will Ferrell          John C. Reilly
# 247                              Christian Bale               Amy Adams
# 248                              Felicity Jones            Armie Hammer
# 249                               Nicole Kidman          Sebastian Stan
#
#         actor_3_name                                     genres  \
# 0     Leigh Whannell                                Documentary
# 1      Emily Althaus                                Drama Crime
# 2     Patrick Wilson            Action Adventure Crime Thriller
# 3        Billy Brown                       Comedy Crime Mystery
# 4      Shawn Ashmore                                Documentary
# ..               ...                                        ...
# 245  Vanessa Hudgens                             Romance Comedy
# 246     Rebecca Hall                       Comedy Mystery Crime
# 247     Steve Carell  Thriller Science Fiction Action Adventure
# 248   Justin Theroux                              Drama History
# 249     Toby Kebbell                                      Drama
#
#                movie_title
# 0           The Final Year
# 1                Bomb City
# 2      The Hurricane Heist
# 3         Super Troopers 2
# 4    Leaning Into The Wind
# ..                     ...
# 245             Second Act
# 246        Holmes & Watson
# 247                   Vice
# 248    On the Basis of Sex
# 249              Destroyer
#
# [250 rows x 6 columns]

# %%
new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df18['movie_title'] = new_df18['movie_title'].str.lower()

# %%
new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']
new_df18
# Out:
#                                          director_name  \
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 245                                        Peter Segal
# 246                                         Etan Cohen
# 247                                         Adam McKay
# 248                                         Mimi Leder
# 249                                       Karyn Kusama
#
#                                    actor_1_name            actor_2_name  \
# 0                                     Lin Shaye           Angus Sampson
# 1    Lauren Wolkstein (director); Alex Pettyfer  James Freedson-Jackson
# 2                                   Liam Neeson            Vera Farmiga
# 3                              Taraji P. Henson    Jahi Di'Allo Winston
# 4                                  Bruce Willis             Cole Hauser
# ..                                          ...                     ...
# 245                              Jennifer Lopez             Leah Remini
# 246                                Will Ferrell          John C. Reilly
# 247                              Christian Bale               Amy Adams
# 248                              Felicity Jones            Armie Hammer
# 249                               Nicole Kidman          Sebastian Stan
#
#         actor_3_name                                     genres  \
# 0     Leigh Whannell                                Documentary
# 1      Emily Althaus                                Drama Crime
# 2     Patrick Wilson            Action Adventure Crime Thriller
# 3        Billy Brown                       Comedy Crime Mystery
# 4      Shawn Ashmore                                Documentary
# ..               ...                                        ...
# 245  Vanessa Hudgens                             Romance Comedy
# 246     Rebecca Hall                       Comedy Mystery Crime
# 247     Steve Carell  Thriller Science Fiction Action Adventure
# 248   Justin Theroux                              Drama History
# 249     Toby Kebbell                                      Drama
#
#                movie_title                                               comb
# 0           the final year  Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1                bomb city  Lauren Wolkstein (director); Alex Pettyfer Jam...
# 2      the hurricane heist  Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# 3         super troopers 2  Taraji P. Henson Jahi Di'Allo Winston Billy Br...
# 4    leaning into the wind  Bruce Willis Cole Hauser Shawn Ashmore Brett D...
# ..                     ...                                                ...
# 245             second act  Jennifer Lopez Leah Remini Vanessa Hudgens Pet...
# 246        holmes & watson  Will Ferrell John C. Reilly Rebecca Hall Etan ...
# 247                   vice  Christian Bale Amy Adams Steve Carell Adam McK...
# 248    on the basis of sex  Felicity Jones Armie Hammer Justin Theroux Mim...
# 249              destroyer  Nicole Kidman Sebastian Stan Toby Kebbell Kary...
#
# [250 rows x 7 columns]

# %% [markdown]
# **Extracting features of 2019 movies from Wikipedia**

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"

headers = {"User-Agent": "Mozilla/5.0"}
response = requests.get(link, headers=headers)

tables = pd.read_html(response.text, header=0)

df1 = tables[2]
df2 = tables[3]
df3 = tables[4]
df4 = tables[5]
# Out:
# C:\Users\youse\AppData\Local\Temp\ipykernel_21736\342872009.py:6: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(response.text, header=0)

# %%
df = pd.concat([df1, df2, df3, df4], ignore_index=True)

# %%
df
# Out:
#              Opening  Opening.1              Title  \
# 0      J A N U A R Y          4        Escape Room
# 1      J A N U A R Y          4         Rust Creek
# 2      J A N U A R Y          4   American Hangman
# 3      J A N U A R Y         11   A Dog's Way Home
# 4      J A N U A R Y         11         The Upside
# ..               ...        ...                ...
# 246  D E C E M B E R         25  Spies in Disguise
# 247  D E C E M B E R         25       Little Women
# 248  D E C E M B E R         25               1917
# 249  D E C E M B E R         25         Just Mercy
# 250  D E C E M B E R         27           Clemency
#
#                                     Production company  \
# 0                    Columbia Pictures / Original Film
# 1                       IFC Films / Lunacy Productions
# 2                          Hangman Justice Productions
# 3                                    Columbia Pictures
# 4                                    STX Entertainment
# ..                                                 ...
# 246  20th Century Fox Animation / Blue Sky Studios ...
# 247            Columbia Pictures / Regency Enterprises
# 248           Universal Pictures / DreamWorks Pictures
# 249                Warner Bros. Pictures / Participant
# 250                                               Neon
#
#                                          Cast and crew   Ref.
# 0    Adam Robitel (director); Bragi F. Schut, Maria...    [2]
# 1    Jen McGowan (director); Julie Lipson (screenpl...    [3]
# 2    Wilson Coneybeare (director/screenplay); Donal...    [4]
# 3    Charles Martin Smith (director); W. Bruce Came...    [5]
# 4    Neil Burger (director); Jon Hartmere (screenpl...    [6]
# ..                                                 ...    ...
# 246  Nick Bruno, Troy Quane (directors); Brad Copel...  [133]
# 247  Greta Gerwig (director/screenplay); Saoirse Ro...  [227]
# 248  Sam Mendes (director/screenplay); Krysty Wilso...  [228]
# 249  Destin Daniel Cretton (director/screenplay), A...  [229]
# 250  Chinonye Chukwu (director/screenplay); Alfre W...  [230]
#
# [251 rows x 6 columns]

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2019 = df[['Title','Cast and crew','genres']]
df_2019
# Out:
#                  Title                                      Cast and crew  \
# 0          Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...
# 1           Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2     American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3     A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4           The Upside  Neil Burger (director); Jon Hartmere (screenpl...
# ..                 ...                                                ...
# 246  Spies in Disguise  Nick Bruno, Troy Quane (directors); Brad Copel...
# 247       Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 248               1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 249         Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 250           Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
#
#                                        genres
# 0                     Horror Thriller Mystery
# 1                 Thriller Drama Action Crime
# 2                                    Thriller
# 3                      Drama Adventure Family
# 4                                Comedy Drama
# ..                                        ...
# 246  Animation Action Adventure Comedy Family
# 247                     Drama Romance History
# 248                  War History Drama Action
# 249                       Drama Crime History
# 250                                     Drama
#
# [251 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\youse\AppData\Local\Temp\ipykernel_21736\2427931457.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# C:\Users\youse\AppData\Local\Temp\ipykernel_21736\21458062.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# C:\Users\youse\AppData\Local\Temp\ipykernel_21736\56863382.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2019 = df_2019.rename(columns={'Title':'movie_title'})

# %%
new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df19['movie_title'] = new_df19['movie_title'].str.lower()

# %%
new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']

# %%
new_df19
# Out:
#               director_name         actor_1_name          actor_2_name  \
# 0              Adam Robitel       Taylor Russell          Logan Miller
# 1               Jen McGowan    Hermione Corfield           Jay Paulson
# 2         Wilson Coneybeare    Donald Sutherland    Vincent Kartheiser
# 3      Charles Martin Smith  Bryce Dallas Howard    Edward James Olmos
# 4               Neil Burger       Bryan Cranston            Kevin Hart
# ..                      ...                  ...                   ...
# 246  Nick Bruno, Troy Quane           Will Smith           Tom Holland
# 247            Greta Gerwig        Saoirse Ronan           Emma Watson
# 248              Sam Mendes        George MacKay  Dean-Charles Chapman
# 249   Destin Daniel Cretton    Michael B. Jordan            Jamie Foxx
# 250         Chinonye Chukwu        Alfre Woodard        Wendell Pierce
#
#          actor_3_name                                    genres  \
# 0    Deborah Ann Woll                   Horror Thriller Mystery
# 1        Sean O'Bryan               Thriller Drama Action Crime
# 2       Oliver Dennis                                  Thriller
# 3     Alexandra Shipp                    Drama Adventure Family
# 4       Nicole Kidman                              Comedy Drama
# ..                ...                                       ...
# 246     Rashida Jones  Animation Action Adventure Comedy Family
# 247     Florence Pugh                     Drama Romance History
# 248       Mark Strong                  War History Drama Action
# 249       Brie Larson                       Drama Crime History
# 250       Aldis Hodge                                     Drama
#
#            movie_title                                               comb
# 0          escape room  Taylor Russell Logan Miller Deborah Ann Woll A...
# 1           rust creek  Hermione Corfield Jay Paulson Sean O'Bryan Jen...
# 2     american hangman  Donald Sutherland Vincent Kartheiser Oliver De...
# 3     a dog's way home  Bryce Dallas Howard Edward James Olmos Alexand...
# 4           the upside  Bryan Cranston Kevin Hart Nicole Kidman Neil B...
# ..                 ...                                                ...
# 246  spies in disguise  Will Smith Tom Holland Rashida Jones Nick Brun...
# 247       little women  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 248               1917  George MacKay Dean-Charles Chapman Mark Strong...
# 249         just mercy  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 250           clemency  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [251 rows x 7 columns]

# %%
my_df = pd.concat([new_df18, new_df19], ignore_index=True)
my_df
# Out:
#                                          director_name  \
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 496                             Nick Bruno, Troy Quane
# 497                                       Greta Gerwig
# 498                                         Sam Mendes
# 499                              Destin Daniel Cretton
# 500                                    Chinonye Chukwu
#
#                                    actor_1_name            actor_2_name  \
# 0                                     Lin Shaye           Angus Sampson
# 1    Lauren Wolkstein (director); Alex Pettyfer  James Freedson-Jackson
# 2                                   Liam Neeson            Vera Farmiga
# 3                              Taraji P. Henson    Jahi Di'Allo Winston
# 4                                  Bruce Willis             Cole Hauser
# ..                                          ...                     ...
# 496                                  Will Smith             Tom Holland
# 497                               Saoirse Ronan             Emma Watson
# 498                               George MacKay    Dean-Charles Chapman
# 499                           Michael B. Jordan              Jamie Foxx
# 500                               Alfre Woodard          Wendell Pierce
#
#        actor_3_name                                    genres  \
# 0    Leigh Whannell                               Documentary
# 1     Emily Althaus                               Drama Crime
# 2    Patrick Wilson           Action Adventure Crime Thriller
# 3       Billy Brown                      Comedy Crime Mystery
# 4     Shawn Ashmore                               Documentary
# ..              ...                                       ...
# 496   Rashida Jones  Animation Action Adventure Comedy Family
# 497   Florence Pugh                     Drama Romance History
# 498     Mark Strong                  War History Drama Action
# 499     Brie Larson                       Drama Crime History
# 500     Aldis Hodge                                     Drama
#
#                movie_title                                               comb
# 0           the final year  Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1                bomb city  Lauren Wolkstein (director); Alex Pettyfer Jam...
# 2      the hurricane heist  Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# 3         super troopers 2  Taraji P. Henson Jahi Di'Allo Winston Billy Br...
# 4    leaning into the wind  Bruce Willis Cole Hauser Shawn Ashmore Brett D...
# ..                     ...                                                ...
# 496      spies in disguise  Will Smith Tom Holland Rashida Jones Nick Brun...
# 497           little women  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 498                   1917  George MacKay Dean-Charles Chapman Mark Strong...
# 499             just mercy  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 500               clemency  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [501 rows x 7 columns]

# %%
old_df = pd.read_csv(r'C:\Users\youse\Desktop\netflix recommendation system\new_data.csv')
old_df
# Out:
#               director_name          actor_1_name            actor_2_name  \
# 0             James Cameron           CCH Pounder        Joel David Moore
# 1            Gore Verbinski           Johnny Depp           Orlando Bloom
# 2                Sam Mendes       Christoph Waltz            Rory Kinnear
# 3         Christopher Nolan             Tom Hardy          Christian Bale
# 4               Doug Walker           Doug Walker              Rob Walker
# ...                     ...                   ...                     ...
# 5359            Jim Strouse      Jessica Williams            Chris O'Dowd
# 5360            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 5361       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 5362  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 5363           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  Unknown                      Documentary
# ...                    ...                              ...
# 5359       Keith Stanfield                   Romance Comedy
# 5360     Jean Louisa Kelly                          Romance
# 5361        Tiitus Rantala                   Romance Comedy
# 5362           Gina Holden       Crime Comedy Action Family
# 5363        Akshaye Khanna             Crime Drama Thriller
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5359                       the incredible jessica james
# 5360                                  can't buy my love
# 5361                   thick lashes of lauri mäntyvaara
# 5362                        cop and a half: new recruit
# 5363                                                mom
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker Unknown Doug Walker Doc...
# ...                                                 ...
# 5359  Jessica Williams Chris O'Dowd Keith Stanfield ...
# 5360  Adelaide Kane Benjamin Hollingsworth Jean Loui...
# 5361  Inka Haapamäki Rosa Honkonen Tiitus Rantala Ha...
# 5362  Lou Diamond Phillips Wallace Shawn Gina Holden...
# 5363  Sridevi Kapoor Sajal Ali Akshaye Khanna Ravi U...
#
# [5364 rows x 7 columns]

# %%
final_df = pd.concat([old_df, my_df],ignore_index=True)
final_df
# Out:
#                director_name       actor_1_name          actor_2_name  \
# 0              James Cameron        CCH Pounder      Joel David Moore
# 1             Gore Verbinski        Johnny Depp         Orlando Bloom
# 2                 Sam Mendes    Christoph Waltz          Rory Kinnear
# 3          Christopher Nolan          Tom Hardy        Christian Bale
# 4                Doug Walker        Doug Walker            Rob Walker
# ...                      ...                ...                   ...
# 5860  Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 5861            Greta Gerwig      Saoirse Ronan           Emma Watson
# 5862              Sam Mendes      George MacKay  Dean-Charles Chapman
# 5863   Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 5864         Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#               actor_3_name                                    genres  \
# 0                Wes Studi           Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport                  Action Adventure Fantasy
# 2         Stephanie Sigman                 Action Adventure Thriller
# 3     Joseph Gordon-Levitt                           Action Thriller
# 4                  Unknown                               Documentary
# ...                    ...                                       ...
# 5860         Rashida Jones  Animation Action Adventure Comedy Family
# 5861         Florence Pugh                     Drama Romance History
# 5862           Mark Strong                  War History Drama Action
# 5863           Brie Larson                       Drama Crime History
# 5864           Aldis Hodge                                     Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5860                                  spies in disguise
# 5861                                       little women
# 5862                                               1917
# 5863                                         just mercy
# 5864                                           clemency
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker Unknown Doug Walker Doc...
# ...                                                 ...
# 5860  Will Smith Tom Holland Rashida Jones Nick Brun...
# 5861  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5862  George MacKay Dean-Charles Chapman Mark Strong...
# 5863  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 5864  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [5865 rows x 7 columns]

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           5
# movie_title      0
# comb             5
# dtype: int64

# %%
final_df = final_df.dropna(how='any')

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
final_df.to_csv('final_data.csv',index=False)
