# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import urllib.request
from tmdbv3api import TMDb
from tmdbv3api import Movie
import json

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"

headers = {"User-Agent": "Mozilla/5.0"}
response = requests.get(link, headers=headers)

soup = BeautifulSoup(response.text, 'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'
# Out:
# C:\Users\youse\AppData\Local\Temp\ipykernel_3196\2803005693.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df1 = pd.read_html(str(tables[0]))[0]
# C:\Users\youse\AppData\Local\Temp\ipykernel_3196\2803005693.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df2 = pd.read_html(str(tables[1]))[0]
# C:\Users\youse\AppData\Local\Temp\ipykernel_3196\2803005693.py:3: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df3 = pd.read_html(str(tables[2]))[0]
# C:\Users\youse\AppData\Local\Temp\ipykernel_3196\2803005693.py:4: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df = pd.concat([df1, df2, df3, df4], ignore_index= True)

# %%
df
# Out:
#              Opening  Opening.1                  Title  \
# 0      J A N U A R Y          3             The Grudge
# 1      J A N U A R Y         10             Underwater
# 2      J A N U A R Y         10            Like a Boss
# 3      J A N U A R Y         10          Three Christs
# 4      J A N U A R Y         10      Inherit the Viper
# ..               ...        ...                    ...
# 274  D E C E M B E R         25       We Can Be Heroes
# 275  D E C E M B E R         25      News of the World
# 276  D E C E M B E R         25  One Night in Miami...
# 277  D E C E M B E R         25  Promising Young Woman
# 278  D E C E M B E R         30      Pieces of a Woman
#
#                                     Production company  \
# 0    Screen Gems / Stage 6 Films / Ghost House Pict...
# 1             20th Century Fox / Chernin Entertainment
# 2                   Paramount Pictures / Artists First
# 3                                            IFC Films
# 4    Lionsgate / Barry Films / Tycor International ...
# ..                                                 ...
# 274  Netflix / Troublemaker Studios / Double R Prod...
# 275  Universal Pictures / Playtone / Perfect World ...
# 276                                     Amazon Studios
# 277          Focus Features / FilmNation Entertainment
# 278                             Netflix / Bron Studios
#
#                                          Cast and crew   Ref.
# 0    Nicolas Pesce (director/screenplay); Andrea Ri...    [2]
# 1    William Eubank (director); Brian Duffield, Ada...    [3]
# 2    Miguel Arteta (director); Sam Pitman, Adam Col...    [4]
# 3    Jon Avnet (director/screenplay); Eric Nazarian...    NaN
# 4    Anthony Jerjen (director); Andrew Crabtree (sc...    [5]
# ..                                                 ...    ...
# 274  Robert Rodriguez (director/screenplay); Priyan...  [247]
# 275  Paul Greengrass (director/screenplay); Luke Da...  [248]
# 276  Regina King (director); Kemp Powers (screenpla...  [249]
# 277  Emerald Fennell (director/screenplay); Carey M...  [250]
# 278  Kornél Mundruczó (director); Kata Wéber (scree...  [251]
#
# [279 rows x 6 columns]

# %%
df_2020 = df[['Title','Cast and crew']]

# %%
df_2020
# Out:
#                      Title                                      Cast and crew
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 274       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 275      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 276  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 277  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 278      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
# [279 rows x 2 columns]

# %%
tmdb = TMDb()
tmdb.api_key = '7fee067b60fd14ed0bd0013b0863045f'

# %%
def get_genre(x):
    try:
        result = tmdb_movie.search(x)
        if not result:
            return np.NaN
        
        movie_id = result[0].id
        url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={tmdb.api_key}"
        response = requests.get(url)
        data = response.json()
        
        genres = data.get("genres", [])
        if genres:
            return " ".join([g["name"] for g in genres])
        else:
            return np.NaN
    except Exception as e:
        print(f"Error for '{x}': {e}")
        return np.NaN

# %%
df_2020["genres"] = df_2020["Title"].map(lambda x: get_genre(str(x)))
# Out:
# Error for 'No films had been released on this date as resulting the closure of theaters caused by the COVID-19 pandemic': attribute name must be string, not 'int'
# Error for 'The SpongeBob Movie: Sponge on the Run (Canadian theatrical release)': attribute name must be string, not 'int'
# C:\Users\youse\AppData\Local\Temp\ipykernel_3196\2613343481.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020["genres"] = df_2020["Title"].map(lambda x: get_genre(str(x)))

# %%
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 274       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 275      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 276  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 277  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 278      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#                                       genres
# 0                    Horror Mystery Thriller
# 1    Horror Science Fiction Action Adventure
# 2                                     Comedy
# 3                                      Drama
# 4                       Crime Thriller Drama
# ..                                       ...
# 274             Family Action Fantasy Comedy
# 275                  Drama Western Adventure
# 276                                    Drama
# 277                     Thriller Crime Drama
# 278                                    Drama
#
# [279 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\youse\AppData\Local\Temp\ipykernel_3196\3848435694.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# C:\Users\youse\AppData\Local\Temp\ipykernel_3196\1815024756.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
#
pieces of a woman  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [249 rows x 7 columns]

# %%
old_df = pd.read_csv('final_data.csv')

# %%
old_df
# Out:
#                director_name       actor_1_name          actor_2_name  \
# 0              James Cameron        CCH Pounder      Joel David Moore
# 1             Gore Verbinski        Johnny Depp         Orlando Bloom
# 2                 Sam Mendes    Christoph Waltz          Rory Kinnear
# 3          Christopher Nolan          Tom Hardy        Christian Bale
# 4                Doug Walker        Doug Walker            Rob Walker
# ...                      ...                ...                   ...
# 5855  Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 5856            Greta Gerwig      Saoirse Ronan           Emma Watson
# 5857              Sam Mendes      George MacKay  Dean-Charles Chapman
# 5858   Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 5859         Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#               actor_3_name                                    genres  \
# 0                Wes Studi           Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport                  Action Adventure Fantasy
# 2         Stephanie Sigman                 Action Adventure Thriller
# 3     Joseph Gordon-Levitt                           Action Thriller
# 4                  Unknown                               Documentary
# ...                    ...                                       ...
# 5855         Rashida Jones  Animation Action Adventure Comedy Family
# 5856         Florence Pugh                     Drama Romance History
# 5857           Mark Strong                  War History Drama Action
# 5858           Brie Larson                       Drama Crime History
# 5859           Aldis Hodge                                     Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5855                                  spies in disguise
# 5856                                       little women
# 5857                                               1917
# 5858                                         just mercy
# 5859                                           clemency
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker Unknown Doug Walker Doc...
# ...                                                 ...
# 5855  Will Smith Tom Holland Rashida Jones Nick Brun...
# 5856  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5857  George MacKay Dean-Charles Chapman Mark Strong...
# 5858  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 5859  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [5860 rows x 7 columns]

# %%
final_df = pd.concat([old_df, new_df20],ignore_index=True)

# %%
final_df
# Out:
#           director_name           actor_1_name      actor_2_name  \
# 0         James Cameron            CCH Pounder  Joel David Moore
# 1        Gore Verbinski            Johnny Depp     Orlando Bloom
# 2            Sam Mendes        Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan              Tom Hardy    Christian Bale
# 4           Doug Walker            Doug Walker        Rob Walker
# ...                 ...                    ...               ...
# 6104        Pete Docter             Jamie Foxx          Tina Fey
# 6105   Robert Rodriguez  Priyanka Chopra Jonas      Pedro Pascal
# 6106        Regina King      Kingsley Ben-Adir         Eli Goree
# 6107    Emerald Fennell         Carey Mulligan        Bo Burnham
# 6108   Kornél Mundruczó          Vanessa Kirby      Shia LaBeouf
#
#               actor_3_name                                 genres  \
# 0                Wes Studi        Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport               Action Adventure Fantasy
# 2         Stephanie Sigman              Action Adventure Thriller
# 3     Joseph Gordon-Levitt                        Action Thriller
# 4                  Unknown                            Documentary
# ...                    ...                                    ...
# 6104         Graham Norton  Animation Family Comedy Fantasy Drama
# 6105         YaYa Gosselin           Family Action Fantasy Comedy
# 6106           Aldis Hodge                                  Drama
# 6107           Alison Brie                   Thriller Crime Drama
# 6108          Molly Parker                                  Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 6104                                               soul
# 6105                                   we can be heroes
# 6106                              one night in miami...
# 6107                              promising young woman
# 6108                                  pieces of a woman
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker Unknown Doug Walker Doc...
# ...                                                 ...
# 6104  Jamie Foxx Tina Fey Graham Norton Pete Docter ...
# 6105  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 6106  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 6107  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 6108  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [6109 rows x 7 columns]

# %%
final_df.to_csv('main_data.csv',index=False)
